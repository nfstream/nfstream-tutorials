# %% [markdown]
# # nfstream: a flexible network data analysis framework

# %% [markdown]
# In this notebook, we will demonstrate how to use nfstream to process your network data

# %%
from nfstream import NFStreamer, NFPlugin
import pandas as pd
pd.set_option('display.max_columns', 500)

# %% [markdown]
# ## From pcap to labelized flows in 1 line

# %%
df = NFStreamer(source="pcaps/instagram.pcap").to_pandas()

# %%
df.head(10)
# Out:
#    id     first_seen      last_seen  version  src_port  dst_port  protocol  \
# 0  27  1436720950909  1436720952614        4        80     58216         6
# 1  19  1436720908533  1436720908579        4     26540        53        17
# 2   6  1436720901182  1436720908544        4     33976        80         6
# 3  23  1436720908581  1436720908769        4     60908       443         6
# 4  29  1436720952561  1436720952561        4     58690       443         6
# 5  25  1436720942530  1436720942621        4     58052        80         6
# 6  26  1436720942580  1436720942580        4     58053        80         6
# 7   9  1436720906022  1436720906022        4     17500     17500        17
# 8  30  1436720952563  1436720952563        4     27124        53        17
# 9  16  1436720908523  1436720908570        4     51219        53        17
#
#    vlan_id         src_ip         dst_ip  total_packets  total_bytes  \
# 0        4    31.13.86.52  192.168.0.103            150       153558
# 1        4  192.168.0.103        8.8.8.8              2          298
# 2        4  192.168.0.103    77.67.29.17             34        29039
# 3        4  192.168.0.103   46.33.70.136             19         9340
# 4        4  192.168.0.103   46.33.70.159              2          169
# 5        4  192.168.0.103   82.85.26.162             75        57239
# 6        4  192.168.0.103   82.85.26.162              1          321
# 7        4  192.168.0.106  192.168.0.255              1          145
# 8        4  192.168.0.103        8.8.8.8              1           85
# 9        4  192.168.0.103        8.8.8.8              2          394
#
#    duration  src2dst_packets  src2dst_bytes  dst2src_packets  dst2src_bytes  \
# 0      1705              103         150456               47           3102
# 1        46                1             89                1            209
# 2      7362               14            924               20          28115
# 3       188               10           1369                9           7971
# 4         0                2            169                0              0
# 5        91               37           2702               38          54537
# 6         0                1            321                0              0
# 7         0                1            145                0              0
# 8         0                1             85                0              0
# 9        47                1             89                1            305
#
#    expiration_id  master_protocol  app_protocol application_name  \
# 0              0                7           119    HTTP.Facebook
# 1              0                5           211    DNS.Instagram
# 2              0                0             7             HTTP
# 3              0               91           211    TLS.Instagram
# 4              0                0            91              TLS
# 5              0                7           211   HTTP.Instagram
# 6              0                7           211   HTTP.Instagram
# 7              0                0           121          Dropbox
# 8              0                5           211    DNS.Instagram
# 9              0                5           211    DNS.Instagram
#
#    category_name                    client_info  \
# 0  SocialNetwork
# 1  SocialNetwork
# 2            Web
# 3  SocialNetwork  igcdn-photos-g-a.akamaihd.net
# 4            Web
# 5  SocialNetwork
# 6  SocialNetwork
# 7          Cloud
# 8  SocialNetwork
# 9  SocialNetwork
#
#                                          server_info  \
# 0
# 1                      igcdn-photos-g-a.akamaihd.net
# 2
# 3  a248.e.akamai.net,*.akamaihd.net,*.akamaihd-st...
# 4
# 5                          photos-g.ak.instagram.com
# 6                          photos-g.ak.instagram.com
# 7
# 8                          photos-b.ak.instagram.com
# 9                      igcdn-photos-h-a.akamaihd.net
#
#                          j3a_client                        j3a_server
# 0
# 1
# 2
# 3  54ae5fcb0159e2ddf6a50e149221c7c7  34d6f0ad0a79e4cfdf145e640cc93f78
# 4
# 5
# 6
# 7
# 8
# 9
